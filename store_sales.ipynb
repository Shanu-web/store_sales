# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Will be performing below operations

# %%
store_data=pd.read_excel(r"superstore_sales.xlsx")

# %% [markdown]
# ## First Five rows of datasets

# %%
store_data.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name    sales  \
# ...

# %% [markdown]
# ## Last Five rows of datasets

# %%
store_data.tail()
# Out:
#              order_id order_date  ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427 2014-12-31 2015-01-04  Standard Class        Erica Bern
# 51286    MO-2014-2560 2014-12-31 2015-01-05  Standard Class         Liz Preis
# 51287  MX-2014-110527 2014-12-31 2015-01-02    Second Class  Charlotte Melton
# 51288  MX-2014-114783 2014-12-31 2015-01-06  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720 2014-12-31 2015-01-04  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Draâ        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %% [markdown]
# ## To fetch top any rows of datasets, say 10

# %%
# Here we are passing 10 in the argumnet so it will display top 10
store_data.head(10)
# Out:
#           order_id order_date  ship_date       ship_mode     customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class   Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class     Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class      Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 5    IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 6     CA-2011-1510 2011-01-02 2011-01-06  Standard Class   Magdelene Morse
# 7    IN-2011-79397 2011-01-03 2011-01-03        Same Day       Kean Nguyen
# 8    ID-2011-80230 2011-01-03 2011-01-09  Standard Class      Ken Lonsdale
# 9     IZ-2011-4680 2011-01-03 2011-01-07  Standard Class  Lindsay Williams
#
#        segment            state      country  market   region  ...  \
# 0     Consumer      Constantine      Algeria  Africa   Africa  ...
# ...

# %% [markdown]
# ## To get the shape of data set

# %%
store_data.shape
# Out:
# (51290, 21)

# %% [markdown]
# ## To get size of data set

# %%
store_data.size
# Out:
# 1077090

# %% [markdown]
# ## To get name of all columns in data set

# %%
store_data.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %% [markdown]
# ## To get concise summary of data set

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  float64
#  15  quantity        51290 non-null  int64
# ...

# %% [markdown]
# ## To check if any missing value present in the data set

# %%
store_data.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %% [markdown]
# ## To get small descriptive summary of data set

# %%
store_data.describe()
# Out:
#               sales      quantity      discount        profit  shipping_cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.641740      26.375818
# std      487.565361      2.278766      0.212280    174.424113      57.296810
# min        0.444000      1.000000      0.000000  -6599.978000       0.002000
# 25%       30.758625      2.000000      0.000000      0.000000       2.610000
# 50%       85.053000      3.000000      0.000000      9.240000       7.790000
# 75%      251.053200      5.000000      0.200000     36.810000      24.450000
# max    22638.480000     14.000000      0.850000   8399.976000     933.570000
#
#                year
# count  51290.000000
# mean    2012.777208
# std        1.098931
# min     2011.000000
# 25%     2012.000000
# 50%     2013.000000
# 75%     2014.000000
# max     2014.000000

# %% [markdown]
# ## To get exploratory data analysis

# %% [markdown]
# #### What is the over all sales trend ?

# %%
# To get the minimum order date
store_data["order_date"].min()
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
#To get the maximum order date
store_data["order_date"].max()
# Out:
# Timestamp('2014-12-31 00:00:00')

# %%
#To create a new column containing order year and month
store_data["order_year_month"]=sales_data["order_date"].apply(lambda val: val.strftime("%Y-%m"))
store_data.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
# ...

# %%
store_data.groupby("order_year_month").sum()
# Out:
#                          sales  quantity  discount       profit  \
# order_year_month
# 2011-01            98898.48886      1463    68.758   8321.80096
# 2011-02            91152.15698      1224    52.252  12417.90698
# 2011-03           145729.36736      1836    74.212  15303.56826
# 2011-04           116915.76418      2020    80.782  12902.32438
# 2011-05           146747.83610      2013    82.382  12183.82870
# 2011-06           215207.38022      3112   159.534  23415.24702
# 2011-07           115510.41912      1774    80.086   5585.00352
# 2011-08           207581.49122      3035   121.462  23713.66772
# 2011-09           290214.45534      3707   137.678  35776.88394
# 2011-10           199071.26404      2727   110.192  25963.41834
# 2011-11           298496.53752      4039   178.836  32709.17772
# 2011-12           333925.73460      4493   187.220  40647.98400
# 2012-01           135780.72024      1845    74.454  10401.63764
# ...

# %%
sales_data=store_data.groupby("order_year_month").sum().sales.reset_index()
sales_data.head()
# Out:
#   order_year_month         sales
# 0          2011-01   98898.48886
# 1          2011-02   91152.15698
# 2          2011-03  145729.36736
# 3          2011-04  116915.76418
# 4          2011-05  146747.83610

# %%
plt.figure(figsize=(16,6))
font1 = {'family':'serif','color':'black','size':20}
font2 = {'family':'serif','color':'blue','size':20}
plt.title("Order monthly sales Analysis",fontdict=font1)
plt.xlabel("month", fontdict=font2)
plt.ylabel("sales", fontdict=font2)
plt.bar(sales_data["order_year_month"],sales_data["sales"], color='y')
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %% [markdown]
# #### Top 10 product by Sales

# %%
product_sales=store_data.groupby("product_name").sum().sales.reset_index()

# %%
top_prod_sales=product_sales.sort_values("sales", ascending=False).head(10)

# %%
top_prod_sales
# Out:
#                                            product_name       sales
# 310                        Apple Smart Phone, Full Size  86935.7786
# 970                        Cisco Smart Phone, Full Size  76441.5306
# 2415                    Motorola Smart Phone, Full Size  73156.3030
# 2501                       Nokia Smart Phone, Full Size  71904.5555
# 866               Canon imageCLASS 2200 Advanced Copier  61599.8240
# 1837         Hon Executive Leather Armchair, Adjustable  58193.4841
# 2631  Office Star Executive Leather Armchair, Adjust...  50661.6840
# 1714  Harbour Creations Executive Leather Armchair, ...  50121.5160
# 2988                      Samsung Smart Phone, Cordless  48653.4600
# 2502                  Nokia Smart Phone, with Caller ID  47877.7857

# %%
plt.figure(figsize=(15,6))
font1 = {'family':'serif','color':'black','size':20}
plt.title("Top 10 product", fontdict=font1)
plt.bar(top_prod_sales["product_name"],top_prod_sales["sales"])
plt.xticks(rotation='vertical', size=12)
plt.show()

# %% [markdown]
# #### Most Selling Product

# %%
most_selling_prod=store_data.groupby("product_name").sum().quantity.reset_index()
most_selling_prod.sort_values("quantity", ascending=False)[:1]
# Out:
#      product_name  quantity
# 3275      Staples       876

# %% [markdown]
# #### Which is the most preferred Ship Mode?

# %%
from collections import Counter
most_shipped=Counter(list(store_data["ship_mode"]))
most_shipped.most_common()[0][0]
# Out:
# 'Standard Class'

# %% [markdown]
#  #### Which are the Most Profitable Category and Sub-Category?

# %%
#Grouping category and sub-category together

profitable_category=pd.DataFrame(store_data.groupby(["category","sub_category"]).sum().profit)

# %%
profitable_category.sort_values(["category","profit"], ascending=False)
# Out:
#                                     profit
# category        sub_category
# Technology      Copiers       258567.54818
#                 Phones        216717.00580
#                 Accessories   129626.30620
#                 Machines       58867.87300
# Office Supplies Appliances    141680.58940
#                 Storage       108461.48980
#                 Binders        72449.84600
#                 Paper          59207.68270
#                 Art            57953.91090
#                 Envelopes      29601.11630
#                 Supplies       22583.26310
#                 Labels         15010.51200
#                 Fasteners      11525.42410
# Furniture       Bookcases     161924.41950
#                 Chairs        141973.79750
#                 Furnishings    46967.42550
#                 Tables        -64083.38870

# %% [markdown]
# # END
